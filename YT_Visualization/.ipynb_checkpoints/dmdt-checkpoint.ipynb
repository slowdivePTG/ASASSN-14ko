# %%
import numpy as np
import yt
import yt.units as u
import matplotlib.pyplot as plt
import os

# %%
from scipy.ndimage.filters import gaussian_filter
from scipy.integrate import simps
from scipy.integrate import cumtrapz
from scipy import interpolate
from scipy import stats
import os
import argparse, sys

# %%
def download_npz(DIR):
    os.chdir('/Users/chang/Desktop/Santa Cruz/TDE_plot')
    flist = os.listdir()
    if not DIR in flist:
        os.system('mkdir {}'.format(DIR))
    os.chdir(DIR)
    os.system(
        'rsync -avz --progress "ptgcliu@fend01.hpc.ku.dk:/storage/dark/ptgcliu/{}/*.npz" .'
        .format(DIR))

# %%
#download_npz('m0.8_p17_b0.6_P50')
#download_npz('m0.8_p17_b0.6_P110')
#download_npz('m0.8_p17_b0.6')
#download_npz('jamie_m1.0_p10_b1.0_300k')
download_npz('jamie_m0.7_p50_b0.8_300k')

# %%
def bins(arr, n):
    arr2 = [arr[i:i + n + 1].mean() for i in range(len(arr) - n)]
    return arr2


#bins(np.arange(100) + np.random.rand(100), 20)

# %%
class dmdt:
    def __init__(self, DIR, chk, Period, D=188 * u.Mpc, eta=0.06, ax=None):
        os.chdir('/Users/chang/Desktop/Santa Cruz/TDE_plot')
        os.chdir(DIR)

        if Period < 0:
            filename = 'b10000_dm_de_chk_{}.npz'.format(chk)
        else:
            filename = 'b10000_dm_de_chk_{}_{}.npz'.format(chk, Period)

        npzfile = np.load(filename)
        output = npzfile['x']
        output_bd = npzfile['y']
        output_mdot = npzfile['z']
        self.DIR, self.Period = DIR, Period
        self.e = output[:, 0]
        self.dm_de, self.s_dm_de = output[:, 1], output[:, 2]

        self.t = output_mdot[:, 0]
        self.mdot, self.mdot_orig = output_mdot[:, 1], output_mdot[:, 2]

        self.F = (self.mdot * u.Msun / u.yr * eta * u.c**2 / np.pi / 4 /
                  D**2).in_units('erg/s/cm**2')
        self.F_orig = (self.mdot_orig * u.Msun / u.yr * eta * u.c**2 / np.pi /
                       4 / D**2).in_units('erg/s/cm**2')

    def dm_de_e(self, ax):
        #dm_de v.s. e
        try:
            if ax == None:
                f, ax = plt.subplots(figsize=(8, 6))
        except:
            pass
        ax.scatter(self.e,
                   self.dm_de,
                   s=0.5,
                   label='{}, P = {}'.format(self.DIR, self.Period))
        ax.set_yscale('log')
        ax.set_xlabel('$\epsilon$ (erg/g)', fontsize=20)
        ax.set_ylabel(r'd$M$/d$\epsilon$ (g$\cdot$s$^2$/cm$^2$)', fontsize=20)

    def Mdot_t(self, ax, Flux=False, norm=False, normfactor=1, Bin=200):
        #Mdot v.s. t
        try:
            if ax == None:
                f, ax = plt.subplots(figsize=(8, 6))
        except:
            pass
        if norm:
            tindex = np.argmax(bins(self.F, Bin))
            ax.scatter(
                (bins(self.t, Bin) - bins(self.t, Bin)[tindex]) * normfactor,
                bins(self.F, Bin) / np.max(bins(self.F, Bin)),
                s=1,
                label='{}, P = {}'.format(self.DIR, self.Period))
            ax.set_ylabel(r'Normalized Flux', fontsize=0)
        elif Flux:
            ax.scatter(self.t, self.F_orig, s=0.1, alpha=0.5)
            ax.scatter(self.t,
                       self.F,
                       s=1,
                       label='{}, P = {}'.format(self.DIR, self.Period))
            ax.set_ylabel(r'$F$ (erg/s/cm$^2$)', fontsize=20)
        else:
            ax.scatter(self.t, self.mdot_orig, s=0.1, alpha=0.5)
            ax.scatter(self.t,
                       self.mdot,
                       s=1,
                       label='{}, P = {}'.format(self.DIR, self.Period))
            ax.set_ylabel(r'$\dot M$ (Msun/yr)', fontsize=20)

        ax.set_xlabel('Time (day)', fontsize=20)
        plt.tight_layout()

# %%
P50_chk0080_114 = dmdt(DIR='m0.8_p17_b0.6_P50', chk='0080', Period=114)
P50_chk0080_50 = dmdt(DIR='m0.8_p17_b0.6_P50', chk='0080', Period=50)
P50_chk0080 = dmdt(DIR='m0.8_p17_b0.6_P50', chk='0080', Period=-1)

P50_chk0060_114 = dmdt(DIR='m0.8_p17_b0.6_P50', chk='0060', Period=114)
P50_chk0060_50 = dmdt(DIR='m0.8_p17_b0.6_P50', chk='0060', Period=50)
P50_chk0060 = dmdt(DIR='m0.8_p17_b0.6_P50', chk='0060', Period=-1)

# %%
P110_chk0080_114 = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=114)
P110_chk0080_50 = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=50)
P110_chk0080 = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=-1)

P110_chk0060_114 = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0060', Period=114)
P110_chk0060_50 = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0060', Period=50)
P110_chk0060 = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0060', Period=-1)

# %%
chk0080_114 = dmdt(DIR='m0.8_p17_b0.6', chk='0080', Period=114)
chk0080_50 = dmdt(DIR='m0.8_p17_b0.6', chk='0080', Period=50)
chk0080 = dmdt(DIR='m0.8_p17_b0.6', chk='0080', Period=-1)

chk0060_114 = dmdt(DIR='m0.8_p17_b0.6', chk='0060', Period=114)
chk0060_50 = dmdt(DIR='m0.8_p17_b0.6', chk='0060', Period=50)
chk0060 = dmdt(DIR='m0.8_p17_b0.6', chk='0060', Period=-1)

# %%
f, ax = plt.subplots(2, 1, figsize=(12, 12), sharex=True)
P50_chk0080_50.dm_de_e(ax=ax[0])
P110_chk0080_114.dm_de_e(ax=ax[0])
chk0080.dm_de_e(ax=ax[0])
P50_chk0080_114.dm_de_e(ax=ax[1])
P110_chk0080_114.dm_de_e(ax=ax[1])
chk0080_114.dm_de_e(ax=ax[1])
f.tight_layout()
ax[0].legend()
ax[1].legend()

# %%
f, ax = plt.subplots(figsize=(12, 6))
P50_chk0080_50.Mdot_t(ax=ax)
P110_chk0080_114.Mdot_t(ax=ax)
chk0080.Mdot_t(ax=ax)
ax.set_xscale('log')
ax.set_yscale('log')
ax.legend()

# %%
f, ax = plt.subplots(3, 1, figsize=(12, 18))
P50_chk0080_114.Mdot_t(ax=ax[0])
P110_chk0080_114.Mdot_t(ax=ax[0])
chk0080_114.Mdot_t(ax=ax[0])
P50_chk0080_50.Mdot_t(ax=ax[1], norm=True, Bin=500)
P110_chk0080_114.Mdot_t(ax=ax[1], norm=True, Bin=500)
chk0080.Mdot_t(ax=ax[1], norm=True, Bin=500)
P50_chk0080_50.Mdot_t(ax=ax[2], norm=True, normfactor=3, Bin=500)
P110_chk0080_114.Mdot_t(ax=ax[2], norm=True, Bin=500)
chk0080.Mdot_t(ax=ax[2], norm=True, normfactor=0.025, Bin=500)
f.tight_layout()
ax[0].set_xscale('log')
ax[0].set_yscale('log')
#ax[0].set_xlim([-2e2,5e3])
#ax[0].set_ylim([1e-2,1.2e0])
ax[1].set_xscale('symlog')
ax[1].set_yscale('log')
ax[1].set_xlim([-1e3, 3e3])
ax[1].set_ylim([1e-2, 1.2e0])
ax[2].set_xscale('symlog')
ax[2].set_yscale('log')
ax[2].set_xlim([-1e3, 3e3])
ax[2].set_ylim([1e-2, 1.2e0])
ax[0].legend()
ax[1].legend()
ax[2].legend()

# %%
jamie_chk0060_114 = dmdt(DIR='jamie_m0.7_p50_b0.8_300k', chk='0060', Period=114)
jamie_chk0060_50 = dmdt(DIR='jamie_m0.7_p50_b0.8_300k', chk='0060', Period=50)
jamie_chk0060 = dmdt(DIR='jamie_m0.7_p50_b0.8_300k', chk='0060', Period=-1)

# %%
f, ax = plt.subplots(figsize=(12, 6))
jamie_chk0060.dm_de_e(ax=ax)

# %%
f, ax = plt.subplots(3, 1, figsize=(12, 18))
jamie_chk0060_50.Mdot_t(ax=ax[0])
jamie_chk0060_114.Mdot_t(ax=ax[0])
jamie_chk0060.Mdot_t(ax=ax[0])
jamie_chk0060_50.Mdot_t(ax=ax[1], norm=True)
jamie_chk0060_114.Mdot_t(ax=ax[1], norm=True)
jamie_chk0060.Mdot_t(ax=ax[1], norm=True)
jamie_chk0060_50.Mdot_t(ax=ax[2], norm=True, normfactor=1.9, Bin=500)
jamie_chk0060_114.Mdot_t(ax=ax[2], norm=True, Bin=500)
jamie_chk0060.Mdot_t(ax=ax[2], norm=True, normfactor=0.3, Bin=500)
f.tight_layout()
ax[0].set_xscale('log')
ax[0].set_yscale('log')
#ax[0].set_xlim([-2e2,5e3])
#ax[0].set_ylim([1e-2,1.2e0])
#ax[1].set_xscale('log')
#ax[1].set_yscale('log')
ax[1].set_ylim([1e-3, 1.2e0])
ax[1].set_xlim([-50, 100])
#ax[2].set_xscale('log')
#ax[2].set_yscale('log')
ax[2].set_ylim([1e-3, 1.2e0])
ax[2].set_xlim([-50, 100])
ax[0].legend()
ax[1].legend()
ax[2].legend()

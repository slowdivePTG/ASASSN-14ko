# %%
import numpy as np
import yt
import yt.units as u
import matplotlib.pyplot as plt
import os

# %%
from scipy.ndimage.filters import gaussian_filter
from scipy.integrate import simps
from scipy.integrate import cumtrapz
from scipy import interpolate
from scipy import stats
import os
import argparse, sys

# %%
def download_npz(DIR):
    os.chdir('/Users/chang/Desktop/Santa Cruz/TDE_plot')
    flist = os.listdir()
    if not DIR in flist:
        os.system('mkdir {}'.format(DIR))
    os.chdir(DIR)
    os.system(
        'rsync -avz --progress "ptgcliu@fend01.hpc.ku.dk:/storage/dark/ptgcliu/{}/*.npz" .'
        .format(DIR))

# %%
'''download_npz('m0.8_p17_b0.6_P50')
download_npz('m0.8_p17_b0.6_P110')
download_npz('m0.8_p17_b0.6')
download_npz('jamie_m1.0_p10_b1.0_300k')'''
# Out:
# "download_npz('m0.8_p17_b0.6_P50')\ndownload_npz('m0.8_p17_b0.6_P110')\ndownload_npz('m0.8_p17_b0.6')\ndownload_npz('jamie_m1.0_p10_b1.0_300k')"

# %%
def bins(arr, n):
    arr2 = [arr[i:i + n + 1].mean() for i in range(len(arr) - n)]
    return arr2


#bins(np.arange(100) + np.random.rand(100), 20)

# %%
def dmdt(DIR,
         chk,
         Period,
         eta=0.06,
         ax=None,
         Flux=False,
         norm=False,
         normfactor=1,
         Bin=200):
    try:
        if ax == None:
            f, ax = plt.subplots(2, 1, figsize=(10, 10))
    except:
        pass
    os.chdir('/Users/chang/Desktop/Santa Cruz/TDE_plot')
    os.chdir(DIR)

    if Period < 0:
        filename = 'b10000_dm_de_chk_{}.npz'.format(chk)
    else:
        filename = 'b10000_dm_de_chk_{}_{}.npz'.format(chk, Period)

    npzfile = np.load(filename)
    output = npzfile['x']
    output_bd = npzfile['y']
    output_mdot = npzfile['z']

    #dm_de v.s. e
    e, dm_de, s_dm_de = output[:, 0], output[:, 1], output[:, 2]
    ax[0].scatter(e, dm_de, s=0.5, label='{}, P = {}'.format(DIR, Period))
    ax[0].set_yscale('log')
    ax[0].set_xlabel('$\epsilon$ (erg/g)', fontsize=20)
    ax[0].set_ylabel(r'd$M$/d$\epsilon$ (g$\cdot$s$^2$/cm$^2$)', fontsize=20)

    #Mdot v.s. t
    t = output_mdot[:, 0]
    mdot, mdot_orig = output_mdot[:, 1], output_mdot[:, 2]
    D = 188 * u.Mpc
    F = (mdot * u.Msun / u.yr * eta * u.c**2 / np.pi / 4 /
         D**2).in_units('erg/s/cm**2')
    F_orig = (mdot_orig * u.Msun / u.yr * eta * u.c**2 / np.pi / 4 /
              D**2).in_units('erg/s/cm**2')
    if norm:
        tindex = np.argmax(bins(F, Bin))
        #ax[1].scatter(t - t[tindex], F_orig / F.max(), s=0.1, alpha=0.5)
        ax[1].scatter((bins(t, Bin) - bins(t, Bin)[tindex]) * normfactor,
                      bins(F, Bin) / np.max(bins(F, Bin)),
                      s=1,
                      label='{}, P = {}'.format(DIR, Period))
    elif Flux:
        ax[1].scatter(t, F_orig, s=0.1, alpha=0.5)
        ax[1].scatter(t, F, s=1, label='{}, P = {}'.format(DIR, Period))
        ax[1].set_ylabel(r'$F$ (erg/s/cm$^2$)', fontsize=0)
    else:
        ax[1].scatter(t, mdot_orig, s=0.1, alpha=0.5)
        ax[1].scatter(t, mdot, s=1, label='{}, P = {}'.format(DIR, Period))
        ax[1].set_ylabel(r'$\dot M$ (Msun/yr)', fontsize=20)

    ax[1].set_xlabel('Time (day)', fontsize=20)
    plt.tight_layout()
    return ax

# %%
ax = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=50, Flux=True)
ax = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=114, Flux=True, ax=ax)
ax = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=-1, Flux=True, ax=ax)
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()

# %%
ax = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=50, norm=True)
ax = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=114, norm=True, ax=ax)
ax = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=-1, norm=True, ax=ax)
#ax[1].set_xscale('log')
ax[1].set_xlim([-50,300])
ax[1].set_ylim([1e-3,1.2e0])
#ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()

# %%
ax = dmdt(DIR='m0.8_p17_b0.6_P50', chk='0080', Period=114, Flux=True)
ax = dmdt(DIR='m0.8_p17_b0.6_P110', chk='0080', Period=114, Flux=True, ax=ax)
ax = dmdt(DIR='m0.8_p17_b0.6', chk='0080', Period=114, Flux=True, ax=ax)
ax[1].set_xscale('log')
ax[1].set_yscale('log')
ax[0].legend()
ax[1].legend()

# %%
ax = dmdt(DIR='jamie_m1.0_p10_b1.0_300k', chk='0060', Period=114, Flux=True)
ax = dmdt(DIR='jamie_m1.0_p10_b1.0_300k', chk='0060', Period=50, Flux=True, ax=ax)
ax = dmdt(DIR='jamie_m1.0_p10_b1.0_300k', chk='0060', Period=-1, Flux=True, ax=ax)
ax[1].set_xscale('log')
ax[1].set_yscale('log')
#ax[1].set_ylim([1e-14, 1e-8])
#ax[1].set_xlim([3e0, 1e3])
ax[0].legend()
ax[1].legend()

# %%
ax = dmdt(DIR='jamie_m1.0_p10_b1.0_300k',
          chk='0060',
          Period=114,
          norm=True)
ax = dmdt(DIR='jamie_m1.0_p10_b1.0_300k',
          chk='0060',
          Period=50,
          norm=True,
          normfactor=2,
          ax=ax)
ax = dmdt(DIR='jamie_m1.0_p10_b1.0_300k',
          chk='0060',
          Period=-1,
          norm=True,
          normfactor=0.33,
          ax=ax)
#ax[1].set_xscale('log')
#ax[1].set_yscale('log')
ax[1].set_ylim([1e-3, 1.2e0])
ax[1].set_xlim([-50, 100])
ax[0].legend()
ax[1].legend()

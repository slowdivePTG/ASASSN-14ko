# %%
# %load_ext autoreload
# %autoreload 2

# %%
import yt
import yt.units as u
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm
'''plt.rcParams.update({
    "text.usetex": True})'''
# Out:
# 'plt.rcParams.update({\n    "text.usetex": True})'

# %%
G = u.gravitational_constant
q0 = 1e6
beta = 1
M = q0 * u.Msun
rT = q0**(1 / 3) * u.Rsun
deltaE = (G * M / rT**2 * u.Rsun).in_cgs()

# %%
dmdt_t0 = np.loadtxt('1.000.dat')

f, ax = plt.subplots(figsize=(10, 8))
ax.set_yscale('log')
ax.set_xlabel(r'$E/\delta E$', fontsize=25)
ax.set_ylabel(r'$\mathrm{d} M$/$\mathrm{d} E$ ($M_\odot/\delta E$)', fontsize=25)
ax.tick_params(labelsize=20)
t0 = dmdt_t0[:, 0]
dmdt0 = dmdt_t0[:, 1]
dedt0 = (2 / 3 * (G**2 * M**2 * np.pi**2 / 2)**(1 / 3) *
         (t0 * u.day)**(-5 / 3)).in_cgs()
dmde0 = (dmdt0 * (u.Msun / u.yr) / dedt0).in_cgs()
E = -((G**2 * M**2 * np.pi**2 / 2)**(1 / 3) * (t0 * u.day)**(-2 / 3)).in_cgs()
E_dE = E / deltaE
dmde_dE = dmde0 * deltaE
ax.plot(E_dE, dmde_dE.in_units('Msun'))
ax.set_yscale('log')

# %%
class TDE:
    def __init__(self, q=q0, Ecc=1, beta=1):
        self.M = q * u.Msun
        self.Ecc = Ecc
        self.beta = beta
        self.rT = q**(1 / 3) * u.Rsun
        self.deltaE = (G * self.M / self.rT**2 * u.Rsun).in_cgs()

        self.E = self.E_Ecc(E_dE * self.deltaE)
        self.T = ((-self.E**3 / 2)**(-1 / 2) * np.pi * G * self.M).in_units('day')

        self.dmde = dmde_dE / self.deltaE
        dedt = 2 / 3 * ((G**2 * self.M**2 * np.pi**2 / 2)**(1 / 3) *
                        self.T**(-5 / 3)).in_cgs()
        self.dmdt = (dedt * self.dmde).in_units('Msun/yr')

        self.Tpeak = self.T[np.argmax(self.dmdt)].in_units('day')
        if self.Eorb == 0:
            self.Period = np.inf
        else:
            self.Period = 2 * np.pi * G * self.M / (-2 * self.Eorb)**(3 / 2)
            self.Period = self.Period.in_units('day')

    def E_Ecc(self, E):
        if self.Ecc == 1:
            self.Eorb = 0
        else:
            a = self.rT / self.beta / (1 - self.Ecc)
            self.Eorb = -G * self.M / 2 / a
        return E + self.Eorb

# %% [markdown]
# ## Tpeak v.s. other parameters

# %%
tpeak = []
P = []
Ecc_range = 1 - np.logspace(-1, -4, 200)
for Ecc in Ecc_range:
    tde = TDE(Ecc=Ecc)
    dmdt_Ecc = tde.dmdt
    P = np.append(P, tde.Period)
    tpeak = np.append(tpeak, tde.Tpeak)
plt.plot(P, tpeak)
#plt.yscale('log')
plt.xscale('log')
plt.xlabel('$\mathrm{Period\ [day]}$')
plt.ylabel('$T_\mathrm{peak}\ \mathrm{[day]}$')
# Out:
# Text(0, 0.5, '$T_\\mathrm{peak}\\ \\mathrm{[day]}$')

# %%
e_cri_1 = 0.9825

# %%
plt.figure(figsize=(10, 10))
q_range = np.logspace(5, 8, 11)
tde0 = [TDE(q=q) for q in q_range]
plt.loglog(q_range, [tde.Tpeak for tde in tde0])

cmap = cm.get_cmap('turbo', 10)

for level, ecc in enumerate(np.linspace(1, e_cri_1, 10)):
    tde_temp = [TDE(q=q, Ecc=ecc) for q in q_range]
    plt.loglog(q_range, [tde.Tpeak for tde in tde_temp], color=cmap(level))
    Tpeak_ratio_analyt_temp = (((1 - ecc) / 2 + q_range**(-1 / 3)) /
                               ((1 - ecc) / 2 + q_range[0]**(-1 / 3)))**(-3 /
                                                                         2)
    '''plt.loglog(q_range,
               tde_temp[0].Tpeak * Tpeak_ratio_analyt_temp,
               color=cmap(level),
               linestyle=':')'''
plt.ylabel('$T_\mathrm{peak}\ \mathrm{[day]}$', fontsize=20)
plt.xlabel('$q$', fontsize=20)
# Out:
# Text(0.5, 0, '$q$')

# %%
cmap = plt.cm.get_cmap('turbo', 10)
for level, ecc in enumerate(np.linspace(e_cri_1, 1 - 1e-5, 10)):
    tde_temp = [TDE(q=q, Ecc=ecc) for q in q_range]
    #plt.loglog(q_range, [tde.Tpeak for tde in tde_temp])
    Tpeak_ratio_analyt_temp = (((1 - ecc) / 2 + q_range**(-1 / 3)) /
                               ((1 - ecc) / 2 + q_range[0]**(-1 / 3)))**(-3 /
                                                                         2)
    plt.loglog(
        q_range,
        abs(tde_temp[0].Tpeak.v * Tpeak_ratio_analyt_temp -
            np.array([tde.Tpeak for tde in tde_temp])) /
        np.array([tde.Tpeak for tde in tde_temp]), color=cmap(level))

# %% [markdown]
# ## Mdot v.s. t

# %%
#P = 114 day, beta = 1, Ecc?
Ecc114 = 1 - ((2 * np.pi / 114 / u.day)**2 / G / u.Msun)**(1 / 3) * u.Rsun
Ecc114
# Out:
# unyt_quantity(0.98989573, '(dimensionless)')

# %%
plt.figure(figsize=(10, 10))
Ecc = [1, Ecc114, e_cri_1]
q_range = np.logspace(5, 8, 7)
cmap = cm.get_cmap('turbo', 5)

for level, ecc in enumerate(Ecc):
    tde_temp = [TDE(q=q, Ecc=ecc) for q in q_range]
    for tde in tde_temp:
        plt.loglog(tde.T, tde.dmdt, color=cmap(level))
plt.ylabel('$\dot M\ [M_\odot/\mathrm{yr}]$', fontsize=20)
plt.xlabel('$T\ \mathrm{[day]}$', fontsize=20)
plt.xlim(1e1, 1e4)
plt.ylim(1e-6, 1e0)
# Out:
# (1e-06, 1.0)

# %%
f, ax = plt.subplots(3, 3, figsize=(18, 18), sharex=True, sharey=True)
ax = ax.flatten()
x, y = np.meshgrid(np.linspace(-5, 5, 100), np.linspace(-5, 5, 100))
z = np.exp(-(x**2+y**2)/2)
for a in ax:
    im = a.imshow(z, cmap='cividis', extent=[-5, 5, -5, 5])
    a.tick_params(labelsize=20)
    a.set_aspect('auto')
for a in ax:
    a.axvline(-1, color='k')
    a.axvline(1, color='k')
plt.subplots_adjust(wspace=0, hspace=0)
cbar = f.colorbar(im, ax=ax.ravel().tolist())

# %%
from mpl_toolkits.axes_grid1 import AxesGrid

f = plt.figure(figsize=(18, 18))

ax = AxesGrid(f,
              111,
              nrows_ncols=(3, 3),
              axes_pad=0,
              cbar_mode='single',
              cbar_location='right',
              cbar_pad=0.1)

x, y = np.meshgrid(np.linspace(-6, 6, 100), np.linspace(-6, 6, 100))
z = np.exp(-(x**2 + y**2) / 2)
for a in ax:
    im = a.imshow(z, cmap='cividis', extent=[-6, 6, -6, 6])
    a.tick_params(labelsize=20)
    a.set_aspect('auto')
    a.set_xticks([-5, 0, 5])
    a.set_yticks([-5, 0, 5])
    xmin, xmax = 0, 100
    for i in z:
        temp = np.argwhere(i > 0.1)
        if len(temp)>0:
            xmin = min(temp)
            xmax = max(temp)
    xmin = xmin / 100 * 12 - 6
    xmax = xmax / 100 * 12 - 6
for a in ax:
    a.axvline(xmin, color='k')
    a.axvline(xmax, color='k')
plt.subplots_adjust(wspace=0, hspace=0)
cbar = a.cax.colorbar(im)
cbar.ax.tick_params(labelsize=20)
#cbar = ax.cbar_axes[0].colorbar(im)
# Out:
# <ipython-input-120-006587af442f>:33: MatplotlibDeprecationWarning: Since 3.2, mpl_toolkits's own colorbar implementation is deprecated; it will be removed two minor releases later.  Set the 'mpl_toolkits.legacy_colorbar' rcParam to False to use Matplotlib's default colorbar implementation and suppress this deprecation warning.
#   cbar = a.cax.colorbar(im)
